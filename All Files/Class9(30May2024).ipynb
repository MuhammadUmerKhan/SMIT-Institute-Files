# %%
import pandas as pd
df = pd.DataFrame({'key': ['b', 'b', 'a', 'c', 'a', 'b'],'data1': range(6)})

# %%
df
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   b      5

# %%
pd.get_dummies(df['key'])
# Out:
#        a      b      c
# 0  False   True  False
# 1  False   True  False
# 2   True  False  False
# 3  False  False   True
# 4   True  False  False
# 5  False   True  False

# %%
df['num'] = df['key'].apply(lambda x: 1 if x=='a' else 2 if x=='b' else 3 if x=='c' else x)

# %%
df
# Out:
#   key  data1  num
# 0   b      0    2
# 1   b      1    2
# 2   a      2    1
# 3   c      3    3
# 4   a      4    1
# 5   b      5    2

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Combining and Merging Datasets

# %%
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openpyxl
#   Downloading openpyxl-3.1.3-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.3-py2.py3-none-any.whl (251 kB)
#    ---------------------------------------- 0.0/251.3 kB ? eta -:--:--
#    ---- ----------------------------------- 30.7/251.3 kB ? eta -:--:--
#    ----------- --------------------------- 71.7/251.3 kB 653.6 kB/s eta 0:00:01
#    -------------------- ----------------- 133.1/251.3 kB 787.7 kB/s eta 0:00:01
#    ---------------------------------------  245.8/251.3 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 251.3/251.3 kB 1.0 MB/s eta 0:00:00
# Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.3

# %%
df0 = pd.read_excel("test_data.xlsx",sheet_name=0)
df1 = pd.read_excel("test_data.xlsx",sheet_name=1)
df2 = pd.read_excel("test_data.xlsx",sheet_name=2)

# %%
df0
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal

# %%
df1
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
df2
# Out:
#   sales_man_name Region   Sales  Amount
# 0           Asad       A    100   100000
# 1        Hussain       B    300   450000
# 2            Ali       C    234   125000
# 3           Sana       D    231   652000
# 4        Fatima        E    324   145000
# 5         Kashif       F    123   825000
# 6         Hassan       G    129   125000
# 7          Almas       H    345   325600
# 8          Fahan       I    400   895200

# %%
pd.concat([df0,df1], axis=0)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
pd.concat([df0,df1],axis=1)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0             1           Asad        Karachi         123   Jawed
# 1             2         Sumair         Lahore         123   Jawed
# 2             3         Farjad        Karachi         145   Najam
# 3             4         Hassan         Lahore         567   Najam
# 4             5          Nasir      Hyderabad         234   Jawed
# 5             6         Kashif      Hyderabad         234  Faisal
# 6             7           Sana         Lahore         567  Faisal
# 7             8         Fatima        Karachi         345   Najam
# 8             9       Abdullah        Karachi         123  Faisal
#
#    sales_man_id sales_man_name sales_man_city  product_id manager
# 0            11          Ahmed        Karachi         123   Jawed
# 1            22           Umer         Lahore         123   Jawed
# 2            33        Huzaifa        Karachi         145   Najam
# 3            44           Asad         Lahore         567   Najam
# 4            55        Hussain      Hyderabad         234   Jawed
# 5            66            Ali      Hyderabad         234  Faisal
# 6            77          Sadaf         Lahore         567  Faisal
# 7            88          Kiran        Karachi         345   Najam
# 8            99            Ali        Karachi         123  Faisal

# %%
pd.concat([df0,df2]).reset_index()
# Out:
#     index  sales_man_id sales_man_name sales_man_city  product_id manager  \
# 0       0           1.0           Asad        Karachi       123.0   Jawed
# 1       1           2.0         Sumair         Lahore       123.0   Jawed
# 2       2           3.0         Farjad        Karachi       145.0   Najam
# 3       3           4.0         Hassan         Lahore       567.0   Najam
# 4       4           5.0          Nasir      Hyderabad       234.0   Jawed
# 5       5           6.0         Kashif      Hyderabad       234.0  Faisal
# 6       6           7.0           Sana         Lahore       567.0  Faisal
# 7       7           8.0         Fatima        Karachi       345.0   Najam
# 8       8           9.0       Abdullah        Karachi       123.0  Faisal
# 9       0           NaN           Asad            NaN         NaN     NaN
# 10      1           NaN        Hussain            NaN         NaN     NaN
# 11      2           NaN            Ali            NaN         NaN     NaN
# 12      3           NaN           Sana            NaN         NaN     NaN
# 13      4           NaN        Fatima             NaN         NaN     NaN
# 14      5           NaN         Kashif            NaN         NaN     NaN
# 15      6           NaN         Hassan            NaN         NaN     NaN
# 16      7           NaN          Almas            NaN         NaN     NaN
# 17      8           NaN          Fahan            NaN         NaN     NaN
#
#    Region   Sales   Amount
# 0      NaN    NaN       NaN
# 1      NaN    NaN       NaN
# 2      NaN    NaN       NaN
# 3      NaN    NaN       NaN
# 4      NaN    NaN       NaN
# 5      NaN    NaN       NaN
# 6      NaN    NaN       NaN
# 7      NaN    NaN       NaN
# 8      NaN    NaN       NaN
# 9        A  100.0  100000.0
# 10       B  300.0  450000.0
# 11       C  234.0  125000.0
# 12       D  231.0  652000.0
# 13       E  324.0  145000.0
# 14       F  123.0  825000.0
# 15       G  129.0  125000.0
# 16       H  345.0  325600.0
# 17       I  400.0  895200.0

# %%
df0.columns
# Out:
# Index(['sales_man_id', 'sales_man_name', 'sales_man_city', 'product_id',
#        'manager'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['sales_man_name', 'Region ', 'Sales', 'Amount '], dtype='object')

# %%
pd.merge(df0, df2)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0             1           Asad        Karachi         123   Jawed       A
# 1             4         Hassan         Lahore         567   Najam       G
# 2             6         Kashif      Hyderabad         234  Faisal       F
# 3             7           Sana         Lahore         567  Faisal       D
#
#    Sales  Amount
# 0    100   100000
# 1    129   125000
# 2    123   825000
# 3    231   652000

# %%
df2['sales_man_name'] = df2.sales_man_name.apply(lambda x: x.strip())

# %%
pd.merge(df0, df2)
# Out:
#    sales_man_id sales_man_name sales_man_city  product_id manager Region   \
# 0             1           Asad        Karachi         123   Jawed       A
# 1             4         Hassan         Lahore         567   Najam       G
# 2             6         Kashif      Hyderabad         234  Faisal       F
# 3             7           Sana         Lahore         567  Faisal       D
# 4             8         Fatima        Karachi         345   Najam       E
#
#    Sales  Amount
# 0    100   100000
# 1    129   125000
# 2    123   825000
# 3    231   652000
# 4    324   145000

# %%
pd.merge(df2, df0)
# Out:
#   sales_man_name Region   Sales  Amount   sales_man_id sales_man_city  \
# 0           Asad       A    100   100000             1        Karachi
# 1           Sana       D    231   652000             7         Lahore
# 2         Fatima       E    324   145000             8        Karachi
# 3         Kashif       F    123   825000             6      Hyderabad
# 4         Hassan       G    129   125000             4         Lahore
#
#    product_id manager
# 0         123   Jawed
# 1         567  Faisal
# 2         345   Najam
# 3         234  Faisal
# 4         567   Najam

# %%
pd.merge(df2, df0,how='outer')
# Out:
#    sales_man_name Region   Sales   Amount   sales_man_id sales_man_city  \
# 0        Abdullah     NaN    NaN       NaN           9.0        Karachi
# 1             Ali       C  234.0  125000.0           NaN            NaN
# 2           Almas       H  345.0  325600.0           NaN            NaN
# 3            Asad       A  100.0  100000.0           1.0        Karachi
# 4           Fahan       I  400.0  895200.0           NaN            NaN
# 5          Farjad     NaN    NaN       NaN           3.0        Karachi
# 6          Fatima       E  324.0  145000.0           8.0        Karachi
# 7          Hassan       G  129.0  125000.0           4.0         Lahore
# 8         Hussain       B  300.0  450000.0           NaN            NaN
# 9          Kashif       F  123.0  825000.0           6.0      Hyderabad
# 10          Nasir     NaN    NaN       NaN           5.0      Hyderabad
# 11           Sana       D  231.0  652000.0           7.0         Lahore
# 12         Sumair     NaN    NaN       NaN           2.0         Lahore
#
#     product_id manager
# 0        123.0  Faisal
# 1          NaN     NaN
# 2          NaN     NaN
# 3        123.0   Jawed
# 4          NaN     NaN
# 5        145.0   Najam
# 6        345.0   Najam
# 7        567.0   Najam
# 8          NaN     NaN
# 9        234.0  Faisal
# 10       234.0   Jawed
# 11       567.0  Faisal
# 12       123.0   Jawed
